# %%
zip_file_path = '/content/drive/MyDrive/Traffic_Sign_YOLOv8/images.zip'

# Extract the zip file to the current directory
# !unzip {zip_file_path} -d /content/drive/MyDrive/Traffic_Sign_YOLOv8

from IPython import display
display.clear_output()

# %%
import os
os.chdir('/content/drive/MyDrive/Traffic_Sign_YOLOv8')

# %%
ls
# Out:
# data.yaml  images/  images.zip  TrafficSignYOLOv8.ipynb

# %%
# !pip install ultralytics==8.0.20

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 26.3/78.2 GB disk)

# %%
# !yolo task=detect mode=train model=yolov8s.pt data= data.yaml epochs=50 imgsz=720 plots=True
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...
